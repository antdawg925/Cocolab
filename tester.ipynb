# %% [markdown]
# <a href="https://colab.research.google.com/github/antdawg925/Cocolab/blob/main/tester.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tensorflow-gpu

# %%
import tensorflow as tf 
print(tf.__version__)
# Out:
# 2.9.1

# %%
import numpy as np
from matplotlib import pyplot as plt

ys = 200 + np.random.randn(100)
x = [x for x in range(len(ys))]

plt.plot(x, ys,"-")
plt.fill_between(x, ys, 195, where=(ys > 195), facecolor='b', alpha=0.6)

plt.title("Sample Visualization")
plt.show
# Out:
# <function matplotlib.pyplot.show>
